# %% [markdown]
# # Домашнее задание 2. Преобразование данных

# %% [markdown]
# Цель этого задания -- преобразовать имеющиеся атрибуты пользователей в признаки так, чтобы полученная матрица признаков была пригодна для подачи в алгоритм кластеризации. Этап конструирования признаков -- самый важный и обычно самый долгий. К нему возвращаются много раз на протяжении решения задачи анализа данных.
#
# Кроме библиотек, использованных в первом задании, нам понадобятся следующие библиотеки:
# 1. [scikit-learn](http://scikit-learn.org/stable/) -- библиотека, реализующая множество алгоритмов машинного обучения и сопутствующих алгоритмов

# %%
import pandas as pd
import numpy as np
import pylab as pl
import sklearn.preprocessing as sp
import csv
import re
import dateutil

np.set_printoptions(linewidth=150, precision=3, suppress=True)

# Plotting config
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
ts_parser = lambda date_str: datetime.datetime.strptime(date_str, "%Y-%m") if pd.notnull(date_str) and date_str else None
df_users = pd.read_csv("hw1_out.csv", sep="\t", encoding="utf-8", quoting=csv.QUOTE_NONNUMERIC, converters={"created_at": ts_parser})

# Remove rows with users not found
df_users = df_users[pd.notnull(df_users['name'])]

df_users["lat"].fillna(value=0, inplace=True)
df_users["lon"].fillna(value=0, inplace=True)

df_users
# Out:
#                       uid  cls                  name      screen_name  \
# 0               202388889  1.0            Kim Salter     mustangkim11
# 1              1392518336  0.0          Tomboy Tarts      TomboyTarts
# 2               361208576  1.0         THE MANC GEEK         BigA85GL
# 3              1535215357  1.0                     L      laurynjiles
# 4              4396196375  1.0     #1stEdifyToUplift    EdifyToUplift
# 5                17938477  1.0       Skelly @SPX B10  SkellyScribbles
# 6      720288026681716737  1.0           Zane Savage     SiNGLEGADGET
# 7               174004739  1.0                  marc     _MightyMarc_
# 8                53783678  1.0          Lady Attis ⚦        ladyattis
# 9               257662370  1.0  Nick Watches Marvel!   NickWatchesMCU
# 10             4795355113  1.0   Superman Cap Marvel   KryptonsWizard
# 11             1633971270  1.0              Van Goth    PikeFishing16
# 12             2803810119  1.0              Ragnarok       Vanguard90
# 13             2244770588  1.0        EssenceCartoon   EssenceCartoon
# 14              102071251  1.0         Dwight Fidler           Kersus
# 15             3358825450  0.0                  Jess     Deadlybarnes
# 16              555940842  1.0                  raya     eIectroheart
# 17             2469354073  0.0        Niche Magazine  NicheMagazineUK
# 18              360464656  0.0        Princess Megan     Laneperson13
# 19               77243076  1.0      Ronelo S. Ladiao     RoneloLadiao
# 20             1731752761  1.0                K33G3N      keegykuehne
# 21             2330149164  0.0                     -      SherliHydra
# 22             2830586398  1.0    Michael T. Johnson  BasicsSuperhero
# 23              443273019  0.0      Matthew Glowacki      nofriends52
# 24             2591381383  0.0     Big Ideas Machine  Bigideasmachine
# 25             1093716612  1.0       Mercedes Conway  AfricasExplorer
# 26               36620392  1.0         Kervyn Cloete    TheKervynator
# 27             3437626995  1.0               Richiee  rickie_rushmore
# 28              387962514  1.0        Andrew Johnson  WrestlingAndrew
# 29             2938363689  1.0          Swagga_Kings      KingsSwagga
# ...                   ...  ...                   ...              ...
# 11914          3101960881  NaN             horrorbro       horrorbro1
# 11915           787761434  NaN             StarChild    StarChild_100
# 11916            70996111  NaN     I AM BLACK SCI-FI    iamblackscifi
# 11917          1551606846  NaN               Dave N.         Dave3Dln
# 11918          2515843570  NaN             Sզմìէէer.    NiftyArachnid
# 11919          3177164330  NaN      Rodrick Long Jr.     ProLionGamer
# 11921            30783602  NaN          b2rian lopez           b2rian
# 11922            23043649  NaN       christine smith  131christine131
# 11923           370117168  NaN        Team Marketing      Team2Market
# 11924           121233392  NaN              10/18 ♎️     AdRianneAdGe
# 11925          3794670447  NaN      Latestcanada.com     latestcanada
# 11926           634578158  NaN             panorina🎨        grizislay
# 11927          1063049935  NaN              Mr-O-Dot          okemawo
# 11928           553917747  NaN            Dave Dixon       Shockdingo
# 11929           628400126  NaN     Bottled Lightning  BottleLightning
# 11930          2450565163  NaN          James Gavsie      JamesGavsie
# 11931            16569278  NaN  CTVMorningLiveOttawa   CTVOttMornLive
# 11932          1944969114  NaN   Trey The PETTY KING      Darude_trey
# 11933            77377177  NaN       KP Kev the Poet       kevthepoet
# 11934          4343171772  NaN          TotalOutplay     totaloutplay
# 11935            33929806  NaN              Han Solo  _TheLastAvenger
# 11936           505986984  NaN              Couchman   Comfy_Couchman
# 11937            15585700  NaN           Kirk Manley         batmankm
# 11939            38068469  NaN              MGiraldi         MGiraldi
# 11940            26628289  NaN                 Isaac         ibot2000
# 11941           249975867  NaN               Rebecca      LiteraryBex
# 11942          3741233607  NaN           Great-Stuff       Splurgehub
# 11944          2818242018  NaN             Tokerware  Tokerwaredotcom
# 11945          2263956151  NaN         Té Nickerson💩   nickerson_taye
# 11946           133581466  NaN          Kayna Storey       lovelyKayn
#
#                                              description verified  \
# 0                 Author- Artist-Marvel-Cars-Books-Music    False
# 1      Celebrating the classic tomboy spirit with a b...    False
# 2      Mancunian geek, blogger/writer/reviewer. Consu...    False
# 3                                I'd rather be in Paris.    False
# 4      Awareness.Advocacy.Ascend🎈 •Focused on buildin...    False
# 5               visual artist, writer, and photographer.    False
# 6      Current gadgets, tech news and reviews, in a s...    False
# 7                                                    NaN    False
# 8      Your friendly neighbor androgynous android. Lo...    False
# 9      Excelsior #TrueBelievers❗️#MCU‼️ #LukeCage 9/3...    False
# 10     The Twitter feed for Superman & Captain Marvel...    False
# 11     I don’t hate your friends. I’m just not intere...    False
# 12                                                   NaN    False
# 13     We make funny cartoons on YouTube. PLEASE SUBS...    False
# 14     Tabletop gamer, theologian, tv watcher, and sm...    False
# 15                                   but he's my friend,    False
# 16     hi im raya!! and i tweet nonsense im sorry | b...    False
# 17                                                   NaN    False
# 18     20yo Canadian cis chick, armchair activist, I ...    False
# 19     I'm back to twitter and it's been a long long ...    False
# 20                  i'm a regular on the tweeter-totter🗣    False
# 21                              I'm a bundle of sadness.    False
# 22     Just a fan of Superheroes trying to get my nam...    False
# 23     Destination still unknown. Let's pray we stay ...    False
# 24     We're a London-based B2B Technology PR & Marke...    False
# 25     Photographer, musician, makeup enthusiast, and...    False
# 26                        Follow me if you want to live.    False
# 27                                Time 4 SUMTHING Stupid    False
# 28     A Lonely Pirate that drifted away from his Mat...    False
# 29     I'm a cool person to get along with. I like me...    False
# ...                                                  ...      ...
# 11914                                                NaN    False
# 11915  I am the StarChild, exploring Space & Timeline...    False
# 11916  https://t.co/xkjVElLUXd is the premier site fo...    False
# 11917                                                NaN    False
# 11918  ↱『ᴇᴠᴇʀʏʙᴏᴅʏ's ғᴀᴠᴏᴜʀɪᴛᴇ sʜᴏᴇ ᴡᴇᴀʀɪɴɢ sᴘɪᴅᴇʀ. ᴘ...    False
# 11919                                                NaN    False
# 11921  i draw pictures and tweet nonsense. follow for...    False
# 11922  I care about all things! #environmental  #Anim...    False
# 11923  We are Team 2 Marketing. Marketing. Social Med...    False
# 11924                  SC: Adrianneadge IG: Adrianneadge    False
# 11925  https://t.co/cz1EEBMr8X is a news aggregator, ...    False
# 11926                                                NaN    False
# 11927                                               True    False
# 11928  #VoiceActor for Kito (TheJourneyDown) Blop (Du...    False
# 11929  Imagination engine and storytelling studio fou...    False
# 11930  #ExecutiveProducer, #Author, #MMA & #BJJ Instr...    False
# 11931  Official account of CTV Morning Live - Ottawa'...     True
# 11932  I speak my mind frequently. My go to is @Simpl...    False
# 11933  The Hip-Hop Bard, poet, MC, singer, sax player...    False
# 11934                       Gameplays or Plays on Games.    False
# 11935                         Life is the biggest troll.    False
# 11936  Most comfortable of all superheroes! Also a re...    False
# 11937  Illustrator, Comic book artist, designer and c...    False
# 11939  An Eagles/Bulls/Blackhawks/White Sox fan. I co...    False
# 11940  Comics. Movies. Music. Good Old Fashioned Love...    False
# 11941  A Writer and a Reader writing about what she r...    False
# 11942                                                NaN    False
# 11944  making something great, be patient.... #Tokerw...    False
# 11945  A little about me: I enjoy long walks on the b...    False
# 11946                                                NaN    False
#
#                           location       lat        lon               country  \
# 0                     Gulfport, FL  27.74836  -82.70343         United States
# 1              Singapore/Malaysia    1.54860  103.52690              Malaysia
# 2                   Manchester, UK  53.48095   -2.23743        United Kingdom
# 3                     Marvel. DC.    0.00000    0.00000                   NaN
# 4          God is my refuge; gem❤️   0.00000    0.00000                   NaN
# 5                     Richmond, VA  37.55376  -77.46026         United States
# 6                 Toronto, Ontario  43.70011  -79.41630                Canada
# 7                              NaN   0.00000    0.00000                   NaN
# 8                  Minneapolis, MN  44.97997  -93.26384         United States
# 9                      Seattle, WA  47.60621 -122.33207         United States
# 10                Rock of Eternity   0.00000    0.00000                   NaN
# 11                             NaN   0.00000    0.00000                   NaN
# 12                             NaN   0.00000    0.00000                   NaN
# 13                       Ohio, USA  39.96118  -82.99879         United States
# 14         Palookaville, Iron City   0.00000    0.00000                   NaN
# 15                             NaN   0.00000    0.00000                   NaN
# 16      layout by kconedits@tumblr   0.00000    0.00000                   NaN
# 17                             NaN   0.00000    0.00000                   NaN
# 18           The Shire, A.K.A. PEI   0.00000    0.00000                   NaN
# 19        Iloilo City, Philippines  10.69694  122.56444           Philippines
# 20                             NaN   0.00000    0.00000                   NaN
# 21                         Area 51   2.96667   35.51667                 Kenya
# 22                     Oakdale, MN  44.96302  -92.96494         United States
# 23                  Cleveland Ohio  41.49950  -81.69541         United States
# 24            City of London, Bank  51.51407   -0.08843        United Kingdom
# 25                   Allentown, PA  40.60843  -75.49018         United States
# 26         Cape Town, South Africa -33.92584   18.42322          South Africa
# 27              Newark, New Jersey  40.73566  -74.17237         United States
# 28                             NaN   0.00000    0.00000                   NaN
# 29                   New York City  40.71427  -74.00597         United States
# ...                            ...       ...        ...                   ...
# 11914                          NaN   0.00000    0.00000                   NaN
# 11915            The Jovian System   0.00000    0.00000                   NaN
# 11916             Philadelphia, PA  39.95233  -75.16379         United States
# 11917                          NaN   0.00000    0.00000                   NaN
# 11918               ᴄʀᴏᴄᴏᴅɪʟᴇ ɪsʟᴇ   0.00000    0.00000                   NaN
# 11919                          NaN   0.00000    0.00000                   NaN
# 11921                  Los Angeles  34.05223 -118.24368         United States
# 11922          Manchester, England  53.48095   -2.23743        United Kingdom
# 11923                       Global  25.06765   55.30557  United Arab Emirates
# 11924                          NaN   0.00000    0.00000                   NaN
# 11925                          NaN   0.00000    0.00000                   NaN
# 11926                        Ελλάς  39.00000   22.00000                Greece
# 11927               Lokoja Nigeria   7.79688    6.74048               Nigeria
# 11928             Toronto, Ontario  43.70011  -79.41630                Canada
# 11929                     Brooklyn  40.65010  -73.94958         United States
# 11930                  Los Angeles  34.05223 -118.24368         United States
# 11931                   Ottawa, ON  45.41117  -75.69812                Canada
# 11932                Arlington, TX  32.73569  -97.10807         United States
# 11933              London, England  51.50853   -0.12574        United Kingdom
# 11934                United States  39.76000  -98.50000         United States
# 11935   If i knew i would tell you   0.00000    0.00000                   NaN
# 11936                          NaN   0.00000    0.00000                   NaN
# 11937       In my Studio working.    0.00000    0.00000                   NaN
# 11939  San Luis Obispo, California  35.28275 -120.65962         United States
# 11940    In Glamourous California    0.00000    0.00000                   NaN
# 11941                          NaN   0.00000    0.00000                   NaN
# 11942                          NaN   0.00000    0.00000                   NaN
# 11944                   Denver, CO  39.73915 -104.98470         United States
# 11945    I don't know, you tell me   0.00000    0.00000                   NaN
# 11946                     Colorado  38.83388 -104.82136         United States
#
#       created_at  followers_count  friends_count  statuses_count  \
# 0     2010-10-01           1052.0         1960.0          9477.0
# 1     2013-04-01           1188.0          835.0         19286.0
# 2     2011-08-01            634.0          576.0          7844.0
# 3     2013-06-01           2362.0         2434.0        187989.0
# 4     2015-12-01           1247.0          961.0         36368.0
# 5     2008-12-01            331.0          497.0          5448.0
# 6     2016-04-01             67.0           70.0          9370.0
# 7     2010-08-01            369.0         1879.0         56344.0
# 8     2009-07-01            755.0         1077.0         39137.0
# 9     2011-02-01            766.0         1374.0         19197.0
# 10    2016-01-01            279.0          406.0           779.0
# 11    2013-07-01            113.0           58.0          7664.0
# 12    2014-10-01             57.0          324.0          3954.0
# 13    2013-12-01          47439.0        24252.0         12466.0
# 14    2010-01-01            344.0          782.0          5662.0
# 15    2015-07-01            343.0          140.0          4544.0
# 16    2012-04-01            431.0          410.0         42363.0
# 17    2014-04-01             86.0           45.0           155.0
# 11917            2125.0           5.0
# 11918               2.0           2.0
# 11919             308.0           1.0
# 11921             308.0           6.0
# 11922            2921.0          65.0
# 11923             139.0          34.0
# 11924             404.0          14.0
# 11925               0.0        1010.0
# 11926           10597.0          25.0
# 11927             750.0           4.0
# 11928           14177.0          34.0
# 11929            1710.0          45.0
# 11930           14848.0         172.0
# 11931             149.0         577.0
# 11932           21291.0           0.0
# 11933            2305.0          53.0
# 11934               1.0           1.0
# 11935            1412.0           2.0
# 11936             506.0           4.0
# 11937              57.0          64.0
# 11939            4159.0          37.0
# 11940            1739.0           4.0
# 11941            2695.0          62.0
# 11942              41.0         115.0
# 11944            1618.0         543.0
# 11945            1014.0           1.0
# 11946             308.0           2.0
#
# [11439 rows x 16 columns]

# %% [markdown]
# Далее необходимо ввести новые признаки. Для каждого пользователя предлагается ввести следующие признаки:
# - name_words - количество слов в имени
# - screen_name_length - количество символов в псевдониме
# - description_length - длина описания
# - created_year - год создания аккаунта
# - country_code - код страны
# - verified - предлагается перевести в тип int
#
# (2 балла)

# %%
# Load countries info (Geonames data)
country_data = pd.read_table("country-data.csv", encoding="utf-8", index_col='name')

def country_code(country_name):
    if pd.isnull(country_name):
        return NaN
    else:
        code = country_data['iso numeric'].get(country_name, NaN)
        return code

def nancheck_len(desc):
    return 0 if pd.isnull(desc) else len(desc)
    
def create_new_features(df_users, features):    
    # Introduce new features
    new_features = [
    #    feature name          column to use  function to apply
        ["name_words",         "name",        lambda name: len(name.split()) ],
        ["screen_name_length", "screen_name", lambda nick: len(nick)         ],
        ["description_length", "description", nancheck_len                   ],
        ["created_year",       "created_at",  lambda date: date.year         ],
        ["country_code",       "country",     country_code                   ],
        ["verified",           "verified",    int                            ]
    ]
    
    # Add new features
    features += [f[0] for f in new_features]
    
    # Apply
    for f in new_features:
        df_users[f[0]] = df_users[f[1]].apply(f[2])
    
    pass

# %%
features = ["lat", "lon", "followers_count", "friends_count", "statuses_count", "favourites_count", "listed_count"]
create_new_features(df_users, features)

x = df_users[pd.notnull(df_users.cls)][features].values
y = df_users[pd.notnull(df_users.cls)]["cls"].values

df_users
# Out:
#                       uid  cls                  name      screen_name  \
# 0               202388889  1.0            Kim Salter     mustangkim11
# 1              1392518336  0.0          Tomboy Tarts      TomboyTarts
# 2               361208576  1.0         THE MANC GEEK         BigA85GL
# 3              1535215357  1.0                     L      laurynjiles
# 4              4396196375  1.0     #1stEdifyToUplift    EdifyToUplift
# 5                17938477  1.0       Skelly @SPX B10  SkellyScribbles
# 6      720288026681716737  1.0           Zane Savage     SiNGLEGADGET
# 7               174004739  1.0                  marc     _MightyMarc_
# 8                53783678  1.0          Lady Attis ⚦        ladyattis
# 9               257662370  1.0  Nick Watches Marvel!   NickWatchesMCU
# 10             4795355113  1.0   Superman Cap Marvel   KryptonsWizard
# 11             1633971270  1.0              Van Goth    PikeFishing16
# 12             2803810119  1.0              Ragnarok       Vanguard90
# 13             2244770588  1.0        EssenceCartoon   EssenceCartoon
# 14              102071251  1.0         Dwight Fidler           Kersus
# 15             3358825450  0.0                  Jess     Deadlybarnes
# 16              555940842  1.0                  raya     eIectroheart
# 17             2469354073  0.0        Niche Magazine  NicheMagazineUK
# 18              360464656  0.0        Princess Megan     Laneperson13
# 19               77243076  1.0      Ronelo S. Ladiao     RoneloLadiao
# 20             1731752761  1.0                K33G3N      keegykuehne
# 21             2330149164  0.0                     -      SherliHydra
# 22             2830586398  1.0    Michael T. Johnson  BasicsSuperhero
# 23              443273019  0.0      Matthew Glowacki      nofriends52
# 24             2591381383  0.0     Big Ideas Machine  Bigideasmachine
# 25             1093716612  1.0       Mercedes Conway  AfricasExplorer
# 26               36620392  1.0         Kervyn Cloete    TheKervynator
# 27             3437626995  1.0               Richiee  rickie_rushmore
# 28              387962514  1.0        Andrew Johnson  WrestlingAndrew
# 29             2938363689  1.0          Swagga_Kings      KingsSwagga
# ...                   ...  ...                   ...              ...
# 11914          3101960881  NaN             horrorbro       horrorbro1
# 11915           787761434  NaN             StarChild    StarChild_100
# 11916            70996111  NaN     I AM BLACK SCI-FI    iamblackscifi
# 11917          1551606846  NaN               Dave N.         Dave3Dln
# 11918          2515843570  NaN             Sզմìէէer.    NiftyArachnid
# 11919          3177164330  NaN      Rodrick Long Jr.     ProLionGamer
# 11921            30783602  NaN          b2rian lopez           b2rian
# 11922            23043649  NaN       christine smith  131christine131
# 11923           370117168  NaN        Team Marketing      Team2Market
# 11924           121233392  NaN              10/18 ♎️     AdRianneAdGe
# 11925          3794670447  NaN      Latestcanada.com     latestcanada
# 11926           634578158  NaN             panorina🎨        grizislay
# 11927          1063049935  NaN              Mr-O-Dot          okemawo
# 11928           553917747  NaN            Dave Dixon       Shockdingo
# 11929           628400126  NaN     Bottled Lightning  BottleLightning
# 11930          2450565163  NaN          James Gavsie      JamesGavsie
# 11931            16569278  NaN  CTVMorningLiveOttawa   CTVOttMornLive
# 11932          1944969114  NaN   Trey The PETTY KING      Darude_trey
# 11933            77377177  NaN       KP Kev the Poet       kevthepoet
# 11934          4343171772  NaN          TotalOutplay     totaloutplay
# 11935            33929806  NaN              Han Solo  _TheLastAvenger
# 11936           505986984  NaN              Couchman   Comfy_Couchman
# 11937            15585700  NaN           Kirk Manley         batmankm
# 11939            38068469  NaN              MGiraldi         MGiraldi
# 11940            26628289  NaN                 Isaac         ibot2000
# 11941           249975867  NaN               Rebecca      LiteraryBex
# 11942          3741233607  NaN           Great-Stuff       Splurgehub
# 11944          2818242018  NaN             Tokerware  Tokerwaredotcom
# 11945          2263956151  NaN         Té Nickerson💩   nickerson_taye
# 11946           133581466  NaN          Kayna Storey       lovelyKayn
#
#                                              description  verified  \
# 0                 Author- Artist-Marvel-Cars-Books-Music         0
# 1      Celebrating the classic tomboy spirit with a b...         0
# 2      Mancunian geek, blogger/writer/reviewer. Consu...         0
# 3                                I'd rather be in Paris.         0
# 4      Awareness.Advocacy.Ascend🎈 •Focused on buildin...         0
# 5               visual artist, writer, and photographer.         0
# 6      Current gadgets, tech news and reviews, in a s...         0
# 7                                                    NaN         0
# 8      Your friendly neighbor androgynous android. Lo...         0
# 5                     Richmond, VA  37.55376  -77.46026         United States
# 6                 Toronto, Ontario  43.70011  -79.41630                Canada
# 7                              NaN   0.00000    0.00000                   NaN
# 8                  Minneapolis, MN  44.97997  -93.26384         United States
# 9                      Seattle, WA  47.60621 -122.33207         United States
# 10                Rock of Eternity   0.00000    0.00000                   NaN
# 11                             NaN   0.00000    0.00000                   NaN
# 12                             NaN   0.00000    0.00000                   NaN
# 13                       Ohio, USA  39.96118  -82.99879         United States
# 14         Palookaville, Iron City   0.00000    0.00000                   NaN
# 15                             NaN   0.00000    0.00000                   NaN
# 16      layout by kconedits@tumblr   0.00000    0.00000                   NaN
# 17                             NaN   0.00000    0.00000                   NaN
# 18           The Shire, A.K.A. PEI   0.00000    0.00000                   NaN
# 19        Iloilo City, Philippines  10.69694  122.56444           Philippines
# 20                             NaN   0.00000    0.00000                   NaN
# 21                         Area 51   2.96667   35.51667                 Kenya
# 22                     Oakdale, MN  44.96302  -92.96494         United States
# 23                  Cleveland Ohio  41.49950  -81.69541         United States
# 24            City of London, Bank  51.51407   -0.08843        United Kingdom
# 25                   Allentown, PA  40.60843  -75.49018         United States
# 26         Cape Town, South Africa -33.92584   18.42322          South Africa
# 27              Newark, New Jersey  40.73566  -74.17237         United States
# 28                             NaN   0.00000    0.00000                   NaN
# 29                   New York City  40.71427  -74.00597         United States
# ...                            ...       ...        ...                   ...
# 11914                          NaN   0.00000    0.00000                   NaN
# 11915            The Jovian System   0.00000    0.00000                   NaN
# 11916             Philadelphia, PA  39.95233  -75.16379         United States
# 11917                          NaN   0.00000    0.00000                   NaN
# 11918               ᴄʀᴏᴄᴏᴅɪʟᴇ ɪsʟᴇ   0.00000    0.00000                   NaN
# 11919                          NaN   0.00000    0.00000                   NaN
# 11921                  Los Angeles  34.05223 -118.24368         United States
# 11922          Manchester, England  53.48095   -2.23743        United Kingdom
# 11923                       Global  25.06765   55.30557  United Arab Emirates
# 11924                          NaN   0.00000    0.00000                   NaN
# 11925                          NaN   0.00000    0.00000                   NaN
# 11926                        Ελλάς  39.00000   22.00000                Greece
# 11927               Lokoja Nigeria   7.79688    6.74048               Nigeria
# 11928             Toronto, Ontario  43.70011  -79.41630                Canada
# 11929                     Brooklyn  40.65010  -73.94958         United States
# 11930                  Los Angeles  34.05223 -118.24368         United States
# 11931                   Ottawa, ON  45.41117  -75.69812                Canada
# 11932                Arlington, TX  32.73569  -97.10807         United States
# 11933              London, England  51.50853   -0.12574        United Kingdom
# 11934                United States  39.76000  -98.50000         United States
# 11935   If i knew i would tell you   0.00000    0.00000                   NaN
# 11936                          NaN   0.00000    0.00000                   NaN
# 11937       In my Studio working.    0.00000    0.00000                   NaN
# 11939  San Luis Obispo, California  35.28275 -120.65962         United States
# 11940    In Glamourous California    0.00000    0.00000                   NaN
# 11941                          NaN   0.00000    0.00000                   NaN
# 11942                          NaN   0.00000    0.00000                   NaN
# 11944                   Denver, CO  39.73915 -104.98470         United States
# 11945    I don't know, you tell me   0.00000    0.00000                   NaN
# 11946                     Colorado  38.83388 -104.82136         United States
# 11925                 145          2015           NaN
# 11926                   0          2012         300.0
# 11927                   4          2013         566.0
# 11928                 158          2012         124.0
# 11929                 158          2012         840.0
# 11930                 160          2014         840.0
# 11931                 140          2008         124.0
# 11932                 160          2013         840.0
# 11933                 109          2009         826.0
# 11934                  28          2015         840.0
# 11935                  26          2009           NaN
# 11936                  63          2012           NaN
# 11937                 127          2008           NaN
# 11939                 159          2009         840.0
# 11940                  52          2009           NaN
# 11941                 109          2011           NaN
# 11942                   0          2015           NaN
# 11944                  64          2014         840.0
# 11945                 143          2013           NaN
# 11946                   0          2010         840.0
#
# [11439 rows x 21 columns]

# %% [markdown]
# Посмотрим, являются ли какие-либо из выбранных признаков сильно скоррелированными. Для этого посчитаем матрицу корреляций и выберем те пары признаков, абсолютное значения коэффициента корреляции между которыми больше 0.2. Необходимо реализовать функцию find_correlated_features, в которой нужно рассчитать коэффициенты корелляции и вывести те, которые больше 0.2. Подсказка: предлагается найти необходимую функцию в библиотеке np и реализовать find_correlated_features с использованием не более 5 строк кода (включая заголовок функции). (2 балла)

# %%
def find_correlated_features(x, features):
    cor = np.corrcoef(x, rowvar=0)
    
    for i, feature_i in enumerate(features):
        for j, feature_j in enumerate(features):
            if i < j and abs(cor[i, j]) > 0.2:
                print "Correlated features: %s + %s -> %.2f" % (feature_i, feature_j, cor[i, j])

# %%
find_correlated_features(x, features)
# Out:
# Correlated features: lat + lon -> -0.63
# Correlated features: followers_count + friends_count -> 0.39
# Correlated features: followers_count + listed_count -> 0.69
# Correlated features: followers_count + verified -> 0.36
# Correlated features: friends_count + listed_count -> 0.38
# Correlated features: statuses_count + favourites_count -> 0.27
# Correlated features: statuses_count + listed_count -> 0.20
# Correlated features: statuses_count + created_year -> -0.21
# Correlated features: listed_count + verified -> 0.35

# %% [markdown]
# Выделилось 3 группы признаков:
# 1. Основанные на географии:  "lat", "lon", "country_code"
# 2. Основанные на социальной активности:  "verified", "followers_count", "friends_count", "statuses_count", "favourites_count", "listed_count", "created_year"
# 3. Остальные:  "name_words", "screen_name_length", "description_length"
#
# Построим взаимные распределения пар признаков в каждой из групп, а также гистограмму значений каждого из признаков с учетом целевой переменной.

# %% [markdown]
# Необходимо реализовать функции: plot_two_features_scatter для построения взаимного распределения пары признаков, plot_feature_histogram для построения гистограммы значений, plot_dataset для построения набора графиков по разным парам признаков. (4 балла)

# %%
def plot_two_features_scatter(x_i, x_j, y):
    colors = ['green' if cls == 1 else 'red' for cls in y]
    pl.scatter(x_j, x_i, c=colors, s=4, linewidth=0, alpha=0.7)
    
    pass

    
def plot_feature_histogram(x_i, y):
    pos = [f for f, cls in zip(x_i, y) if cls == 1 and pd.notnull(f)]
    neg = [f for f, cls in zip(x_i, y) if cls == 0 and pd.notnull(f)]
    
    pl.hist([pos, neg], color=['green', 'red'], alpha=0.7)
    
    pass


def plot_dataset(x, y, features):
    f = pl.figure(figsize=(15, 15))
    
    for i, feature_i in enumerate(features):
        for j, feature_j in enumerate(features):
            f.add_subplot(len(features), len(features), i * len(features) + (j + 1), xticklabels=[], yticklabels=[])
            
            if i == 0:
                pl.title(feature_j)
            
            if j == 0:
                pl.ylabel(feature_i)

            # Do actual plotting
            if i != j:
                plot_two_features_scatter(x[:, i], x[:, j], y)            
            else:
                plot_feature_histogram(x[:, i], y)
    
    pl.show()

# %% [markdown]
# Построим попарные распределения географических признаков ([подсказка](http://stroykova.github.io/sphera/l2_1.png)).

# %%
geo_features_new = ["lat", "lon", "country_code"]

geo_features = [f for f in geo_features_new if f in features]
geo_feature_ind = [features.index(f) for f in geo_features]

plot_dataset(x[:, geo_feature_ind], y, geo_features)

# %% [markdown]
# Четко видны очертания карты и то, что большинство пользователей происходят из небольшого набора стран. Если принять во внимание конечную цель -- кластеризацию пользователей -- логично предположить, что использование географических признаков для описания пользователя может оказаться не очень полезным. Причина в том, что эти признаки четко пространственно разделены (как минимум, океанами и морями). Поэтому мы рискуем вместо "интересной" кластеризации получить просто кластеры, которые будут представлять разные страны. В дальнейшем мы исключим географические признаки из рассмотрения при кластеризации пользователей.
#
# Далее построим попарные распределения социальных признаков ([подсказка](http://stroykova.github.io/sphera/l2_2.png)).

# %%
social_features_new = ["verified", "followers_count", "friends_count", "statuses_count", "favourites_count", "listed_count", "created_year"]

social_features = [f for f in social_features_new if f in features]
social_feature_ind = [features.index(f) for f in social_features]

plot_dataset(x[:, social_feature_ind], y, social_features)

# %% [markdown]
# Из графиков видно, что признаки "followers_count", "friends_count", "statuses_count", "favourites_count", "listed_count" сильно смещены в сторону небольших значений. В таком случае удобно сделать логарифмическое преобразрвание этих признаков, то есть применить к их значениям $x_{ij}$ функцию $\log(1 + x_{ij})$. Сделаем это и построим новые распределения ([подсказка](http://stroykova.github.io/sphera/l2_3.png)). Необходимо реализовать функцию log_transform_features, которая выполняет указанное логарифмическое преобразование. (2 балла)

# %%
def log_transform_features(data, features, transformed_features):
    transformed_feature_ind = [features.index(f) for f in transformed_features]
    
    data[:, transformed_feature_ind] = np.log(1 + data[:, transformed_feature_ind])
    
    pass

# %%
transformed_features = ["followers_count", "friends_count", "statuses_count", "favourites_count", "listed_count"]
log_transform_features(x, features, transformed_features)

# Re-plot features
plot_dataset(x[:, social_feature_ind], y, social_features)

# %% [markdown]
# Сразу бросается в глаза, что признак "verified" сильно смещен -- верифицированных пользователей очень мало. Более того, все верифицированные пользователи имеют много фолловеров, поэтому часть информации о верификации дублируется в признаке "followers_count". По этой причине в дальнейшем не будем рассматривать признак "verified".
#
# После того как мы с помощью логарифмического преобразования избавились от сильной скошенности признаков, можно наблюдать некоторые интересные зависимости. Например, пользователи, имеющие много фолловеров, обязательно имеют много статусов. Следовательно, чтобы стать популярным, обязательно нужно много писать. Анализ других зависимостей остается как упражнение.
#
# Наконец построим попарные распределения остальных признаков ([подсказка](http://stroykova.github.io/sphera/l2_4.png)).

# %%
other_features_new = ["name_words", "screen_name_length", "description_length"]

other_features = [f for f in other_features_new if f in features]
other_feature_ind = [features.index(f) for f in other_features]

plot_dataset(x[:, other_feature_ind], y, other_features)

# %% [markdown]
# Итак после первичной обработки данных мы имеем 9 числовых признаков, каждый из которых распределен в некотором своем интервале. Для того, чтобы ни один признак не получил перевеса при кластеризации, нормализуем данные так, что каждый признак распределен на отрезке $[0, 1]$.

# %%
selected_features = ["followers_count", "friends_count", "statuses_count", "favourites_count", 
                     "listed_count", "created_year", "name_words", "screen_name_length", "description_length"]

x_1 = df_users[selected_features].values
y = df_users["cls"].values

# x_1 = x[:, selected_features_ind]
# Replace nan with 0-s
# Is there a smarter way?
x_1[np.isnan(x_1)] = 0
x_min = x_1.min(axis=0)
x_max = x_1.max(axis=0)
x_new = (x_1 - x_min) / (x_max - x_min)

# %% [markdown]
# Упакуем полученную матрицу в pandas DataFrame и сохраним в файл "hw2_out.csv". В следующем задании мы будем кластеризовать пользователей на оновании этих данных.

# %%
df_out = pd.DataFrame(data=x_new, index=df_users["uid"], columns=[f for f in selected_features])
df_out.to_csv("hw2_out.csv", sep="\t")

df_out
# Out:
#                     followers_count  friends_count  statuses_count  \
# uid
# 202388889              2.532612e-04       0.006693        0.008612
# 1392518336             2.860022e-04       0.002851        0.017534
# 361208576              1.526308e-04       0.001967        0.007127
# 1535215357             5.686340e-04       0.008312        0.170977
# 4396196375             3.002060e-04       0.003282        0.033071
# 17938477               7.968580e-05       0.001697        0.004948
# 720288026681716737     1.612975e-05       0.000239        0.008515
# 174004739              8.883402e-05       0.006416        0.051240
# 53783678               1.817607e-04       0.003678        0.035590
# 257662370              1.844088e-04       0.004692        0.017453
# 4795355113             6.716719e-05       0.001386        0.000701
# 1633971270             2.720391e-05       0.000198        0.006963
# 2803810119             1.372233e-05       0.001106        0.003589
# 2244770588             1.142059e-02       0.082816        0.011331
# 102071251              8.281546e-05       0.002670        0.005143
# 3358825450             8.257471e-05       0.000478        0.004126
# 555940842              1.037601e-04       0.001400        0.038524
# 2469354073             2.070386e-05       0.000154        0.000134
# 360464656              9.485259e-05       0.002814        0.074405
# 77243076               2.166683e-05       0.000645        0.011175
# 1731752761             3.611139e-06       0.000140        0.000043
# 2330149164             1.042415e-04       0.001612        0.023181
# 2830586398             4.092624e-05       0.001359        0.001080
# 443273019              5.296337e-05       0.000577        0.009799
# 2591381383             1.425437e-03       0.005969        0.003012
# 1093716612             3.707436e-05       0.000840        0.002724
# 36620392               1.285566e-04       0.004251        0.029263
# 3437626995             4.333367e-06       0.000143        0.000060
# 387962514              1.295195e-04       0.012932        0.001238
# 2938363689             1.588901e-05       0.000478        0.000411
# ...                             ...            ...             ...
# 3101960881             9.629704e-07       0.000137        0.006070
# 787761434              3.530129e-02       0.491975        0.060451
# 70996111               4.198551e-04       0.000604        0.001027
# 1551606846             4.574109e-06       0.000253        0.000659
# 2515843570             9.629704e-05       0.000690        0.000005
# 3177164330             1.468530e-05       0.000324        0.000866
# 30783602               5.946342e-05       0.000232        0.005733
# 23043649               1.367418e-04       0.003466        0.007001
# 370117168              9.340813e-05       0.000700        0.106178
# 121233392              2.236499e-04       0.001093        0.079652
# 3794670447             1.579271e-04       0.000253        0.181073
# 634578158              1.495252e-03       0.000505        0.066870
# 1063049935             1.179639e-05       0.000222        0.001279
# 553917747              7.920432e-05       0.002851        0.005405
